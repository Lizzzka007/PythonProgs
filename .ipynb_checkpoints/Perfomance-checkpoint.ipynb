# %%
import matplotlib.pyplot as plt

# %% [markdown]
# div2x

# %%
GPU =     [0.002621, 0.006200, 0.031509, 0.057759, 0.391489, 3.034166, 24.529760]
CPU_n1  = [0.00464, 0.03722, 0.27189, 0.52578, 4.57393, 57.45157, 449.75486]
CPU_n14 = [0.00049, 0.00335, 0.02437, 0.03879, 0.40486, 16.25225, 138.76755]
AngleStep = [4, 2, 1, 0.8, 0.4, 0.2, 0.1] 

fig, ax = plt.subplots(figsize=(12,12))
plt.xlabel("Шаг сетки, градусы", fontsize=16)
plt.ylabel("Время, секунды", fontsize=16)
ax.plot(AngleStep, CPU_n1, marker='o', label="CPU n1")
ax.plot(AngleStep, CPU_n14, marker='o', label="CPU n14")
ax.plot(AngleStep, GPU, marker='o', label="GPU")
ax.legend(fontsize = 16, loc='best')
plt.title("div-x2", fontsize=24);

# %% [markdown]
# upwind

# %%
GPU =     [0.002702, 0.006420, 0.031538, 0.058142, 0.398017, 3.061037, 24.867944]
CPU_n1  = [0.00754, 0.05387, 0.31929, 0.59412, 5.03436, 59.84058, 455.49874]
CPU_n14 = [0.00058, 0.00282, 0.02085, 0.04166, 0.44408, 16.14420, 138.60793]
AngleStep = [4, 2, 1, 0.8, 0.4, 0.2, 0.1] 

fig, ax = plt.subplots(figsize=(12,12))
plt.xlabel("Шаг сетки, градусы", fontsize=16)
plt.ylabel("Время, секунды", fontsize=16)
ax.plot(AngleStep, CPU_n1, marker='o', label="CPU n1")
ax.plot(AngleStep, CPU_n14, marker='o', label="CPU n14")
ax.plot(AngleStep, GPU, marker='o', label="GPU")
ax.legend(fontsize = 16, loc='best')
plt.title("upwind", fontsize=24);

# %% [markdown]
# upwind_x3

# %%
GPU =     [0.002917, 0.007535, 0.036585, 0.065961, 0.429757, 3.238684, 25.861751]
CPU_n1  = [0.01463, 0.11145, 0.84903, 1.63029, 12.46627, 112.13326, 926.94796]
CPU_n14 = [0.00146, 0.00865, 0.06557, 0.12522, 1.09192, 15.57897, 138.92830]
AngleStep = [4, 2, 1, 0.8, 0.4, 0.2, 0.1] 

fig, ax = plt.subplots(figsize=(12,12))
plt.xlabel("Шаг сетки, градусы", fontsize=16)
plt.ylabel("Время, секунды", fontsize=16)
ax.plot(AngleStep, CPU_n1, marker='o', label="CPU n1")
ax.plot(AngleStep, CPU_n14, marker='o', label="CPU n14")
ax.plot(AngleStep, GPU, marker='o', label="GPU")
ax.legend(fontsize = 16, loc='best')
plt.title("$upwind_{X3}$", fontsize=24);

# %% [markdown]
# Lax-Wendroff flux limiter

# %%
GPU =     [0.003882, 0.011849, 0.063894, 0.124220, 0.876054, ]
CPU_n1  = [0.04074, 0.28831, 2.43620, 4.26987, 34.65315, 316.53729, 2384.24660]
CPU_n14 = [0.00237, 0.01121, 0.08727, 0.17513, 1.44651, 15.65171, 139.60063]
AngleStep = [4, 2, 1, 0.8, 0.4, 0.2, 0.1] 

fig, ax = plt.subplots(figsize=(12,12))
plt.xlabel("Шаг сетки, градусы", fontsize=16)
plt.ylabel("Время, секунды", fontsize=16)
ax.plot(AngleStep, CPU_n1, marker='o', label="CPU n1")
ax.plot(AngleStep, CPU_n14, marker='o', label="CPU n14")
ax.plot(AngleStep, GPU, marker='o', label="GPU")
ax.legend(fontsize = 16, loc='best')
plt.title("Lax-wendroff flux limiter", fontsize=24);

# %% [markdown]
# GPU в зависимости от сетки

# %%
div2x = [0.002621, 0.006200, 0.031509, 0.057759, 0.391489, 3.034166, 24.529760]
upwind = [0.002702, 0.006420, 0.031538, 0.058142, 0.398017, 3.061037, 24.867944]
upwind_x3 = [0.002917, 0.007535, 0.036585, 0.065961, 0.429757, 3.238684, 25.861751]
# lax = [0.00914, 0.02003, 0.10154, 0.21840, 1.52069, 16.22162, 143.78663]

fig, ax = plt.subplots(figsize=(12,12))
plt.xlabel("Шаг сетки, градусы", fontsize=16)
plt.ylabel("Время, секунды", fontsize=16)
ax.plot(AngleStep, div2x, marker='o', lw=3, label="div-2x")
ax.plot(AngleStep, upwind, marker='o', label="upwind")
ax.plot(AngleStep, upwind_x3, marker='o', label="$upwind_{x3}$")
# ax.plot(AngleStep, lax, marker='o', label="Lax-Wendroff flux limiter")
ax.legend(fontsize = 16, loc='best')
plt.title("GPU в зависимости от сетки", fontsize=24);

# %% [markdown]
# CPU n1 в зависимости от сетки

# %%
div2x = [0.00464, 0.03722, 0.27189, 0.52578, 4.57393, 57.45157, 449.75486]
upwind = [0.00754, 0.05387, 0.31929, 0.59412, 5.03436, 59.84058, 455.49874]
upwind_x3 = [0.01463, 0.11145, 0.84903, 1.63029, 12.46627, 112.13326, 926.94796]
lax = [0.04074, 0.28831, 2.43620, 4.26987, 34.65315, 316.53729, 2384.24660]

fig, ax = plt.subplots(figsize=(12,12))
plt.xlabel("Шаг сетки, градусы", fontsize=16)
plt.ylabel("Время, секунды", fontsize=16)
ax.plot(AngleStep, div2x, marker='o', lw=3, label="div-2x")
ax.plot(AngleStep, upwind, marker='o', label="upwind")
ax.plot(AngleStep, upwind_x3, marker='o', label="$upwind_{x3}$")
ax.plot(AngleStep, lax, marker='o', label="Lax-Wendroff flux limiter")
ax.legend(fontsize = 16, loc='best')
plt.title("CPU n1 в зависимости от сетки", fontsize=24);

# %% [markdown]
# CPU n14 в зависимости от сетки

# %%
div2x = [0.00049, 0.00335, 0.02437, 0.03879, 0.40486, 16.25225, 138.76755]
upwind = [0.00058, 0.00282, 0.02085, 0.04166, 0.44408, 16.14420, 138.60793]
upwind_x3 = [0.00146, 0.00865, 0.06557, 0.12522, 1.09192, 15.57897, 138.92830]
lax = [0.00237, 0.01121, 0.08727, 0.17513, 1.44651, 15.65171, 139.60063]

fig, ax = plt.subplots(figsize=(12,12))
plt.xlabel("Шаг сетки, градусы", fontsize=16)
plt.ylabel("Время, секунды", fontsize=16)
ax.plot(AngleStep, div2x, marker='o', lw=3, label="div-2x")
ax.plot(AngleStep, upwind, marker='o', label="upwind")
ax.plot(AngleStep, upwind_x3, marker='o', label="$upwind_{x3}$")
ax.plot(AngleStep, lax, marker='o', label="Lax-Wendroff flux limiter")
ax.legend(fontsize = 16, loc='best')
plt.title("CPU n14 в зависимости от сетки", fontsize=24);
